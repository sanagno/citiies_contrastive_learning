# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import numpy as np
from torch.utils.data import Dataset, DataLoader
import json
import os
import glob
from geopy.geocoders import Nominatim
import re
import pandas as pd
from torchvision.io import read_image
from sklearn.preprocessing import LabelEncoder
from torch.utils.tensorboard import SummaryWriter
import sklearn
from torchvision.transforms import InterpolationMode
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedShuffleSplit
import math
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
torch.cuda.current_device()
torch.cuda.set_device(0)
print(torch.cuda.mem_get_info(torch.cuda.current_device()))
device = torch.cuda.current_device()
# Out:
# (94101699767216, 94101591103652)

# %%
# Hyper-parameters 
num_epochs = 80
batch_size = 5
learning_rate = 0.01

# %%
image_id_and_labels_train = pd.read_csv('ids_and_labels_train.csv',delimiter=',',header=1)
image_id_and_labels_train_arr = np.array(image_id_and_labels_train.values)
image_id_and_labels_val = pd.read_csv('ids_and_labels_val.csv',delimiter=',',header=1)
image_id_and_labels_val_arr = np.array(image_id_and_labels_val.values)
print(image_id_and_labels_train_arr)
print(image_id_and_labels_val_arr)
# Out:
# [['global_monthly_2018_12_mosaic_L15-1025E-1366N_4102_2726_13.tif'
#   'Dartford' 'England' 17]
#  ['global_monthly_2018_05_mosaic_L15-0387E-1276N_1549_3087_13.tif' 'Lehi'
#   'Utah' 18]
#  ['global_monthly_2018_06_mosaic_L15-1716E-1211N_6864_3345_13.tif' '浦东新区'
#   nan 29]
#  ...
#  ['global_monthly_2018_09_mosaic_L15-0614E-0946N_2459_4406_13.tif'
#   'San Sebastián' 'Cusco' 11]
#  ['global_monthly_2018_09_mosaic_L15-0924E-1108N_3699_3757_13.tif'
#   'Dakar' 'Région de Dakar' 15]
#  ['global_monthly_2019_12_mosaic_L15-1172E-1306N_4688_2967_13.tif' nan
#   nan 13]]
# [['global_monthly_2019_12_mosaic_L15-1748E-1247N_6993_3202_13.tif' '세종'
#   nan 30]
#  ['global_monthly_2019_04_mosaic_L15-1672E-1207N_6691_3363_13.tif' '武汉市'
#   '湖北省' 29]
#  ['global_monthly_2019_03_mosaic_L15-1615E-1206N_6460_3366_13.tif' '成都市'
#   '四川省' 29]
#  ...
#  ['global_monthly_2019_07_mosaic_L15-1615E-1205N_6460_3370_13.tif' nan
#   '四川省' 29]
#  ['global_monthly_2018_12_mosaic_L15-0387E-1276N_1549_3087_13.tif' 'Lehi'
#   'Utah' 18]
#  ['global_monthly_2018_04_mosaic_L15-1014E-1375N_4056_2688_13.tif' nan
#   'England' 17]]

# %%
repeated_ids_labels_train = np.repeat(image_id_and_labels_train_arr, repeats=16, axis=0)
repeated_ids_labels_val = np.repeat(image_id_and_labels_val_arr, repeats=16, axis=0)
print(repeated_ids_labels_train)
# Out:
# [['global_monthly_2018_12_mosaic_L15-1025E-1366N_4102_2726_13.tif'
#   'Dartford' 'England' 17]
#  ['global_monthly_2018_12_mosaic_L15-1025E-1366N_4102_2726_13.tif'
#   'Dartford' 'England' 17]
#  ['global_monthly_2018_12_mosaic_L15-1025E-1366N_4102_2726_13.tif'
#   'Dartford' 'England' 17]
#  ...
#  ['global_monthly_2019_12_mosaic_L15-1172E-1306N_4688_2967_13.tif' nan
#   nan 13]
#  ['global_monthly_2019_12_mosaic_L15-1172E-1306N_4688_2967_13.tif' nan
#   nan 13]
#  ['global_monthly_2019_12_mosaic_L15-1172E-1306N_4688_2967_13.tif' nan
#   nan 13]]

# %%
patch_index = 0
for row in range(repeated_ids_labels_train.shape[0]):
    repeated_ids_labels_train[row,0] = str(patch_index%16) + '!' + repeated_ids_labels_train[row,0] 
    patch_index += 1
print(repeated_ids_labels_train)
# Out:
# [['0!global_monthly_2018_12_mosaic_L15-1025E-1366N_4102_2726_13.tif'
#   'Dartford' 'England' 17]
#  ['1!global_monthly_2018_12_mosaic_L15-1025E-1366N_4102_2726_13.tif'
#   'Dartford' 'England' 17]
#  ['2!global_monthly_2018_12_mosaic_L15-1025E-1366N_4102_2726_13.tif'
#   'Dartford' 'England' 17]
#  ...
#  ['13!global_monthly_2019_12_mosaic_L15-1172E-1306N_4688_2967_13.tif' nan
#   nan 13]
#  ['14!global_monthly_2019_12_mosaic_L15-1172E-1306N_4688_2967_13.tif' nan
#   nan 13]
#  ['15!global_monthly_2019_12_mosaic_L15-1172E-1306N_4688_2967_13.tif' nan
#   nan 13]]

# %%
patch_index = 0
for row in range(repeated_ids_labels_val.shape[0]):
    repeated_ids_labels_val[row,0] = str(patch_index%16) + '!' + repeated_ids_labels_val[row,0] 
    patch_index += 1
print(repeated_ids_labels_val)
# Out:
# [['0!global_monthly_2019_12_mosaic_L15-1748E-1247N_6993_3202_13.tif' '세종'
#   nan 30]
#  ['1!global_monthly_2019_12_mosaic_L15-1748E-1247N_6993_3202_13.tif' '세종'
#   nan 30]
#  ['2!global_monthly_2019_12_mosaic_L15-1748E-1247N_6993_3202_13.tif' '세종'
#   nan 30]
#  ...
#  ['13!global_monthly_2018_04_mosaic_L15-1014E-1375N_4056_2688_13.tif' nan
#   'England' 17]
#  ['14!global_monthly_2018_04_mosaic_L15-1014E-1375N_4056_2688_13.tif' nan
#   'England' 17]
#  ['15!global_monthly_2018_04_mosaic_L15-1014E-1375N_4056_2688_13.tif' nan
#   'England' 17]]

# %% [markdown]
# ## MIXED

# %%
repeated_ids_labels_overall = np.concatenate((repeated_ids_labels_train, repeated_ids_labels_val), axis=0)
print(repeated_ids_labels_overall.shape)
# Out:
# (22688, 4)

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedShuffleSplit

stratSplit = StratifiedShuffleSplit(n_splits=1, test_size = 0.25, random_state=42)
for train_idx, test_idx in stratSplit.split(repeated_ids_labels_overall, np.zeros(len(repeated_ids_labels_overall))):
    ids_labels_train, ids_labels_val = repeated_ids_labels_overall[train_idx], repeated_ids_labels_overall[test_idx]
    
print(ids_labels_train.shape)
    
print(ids_labels_val.shape)
# Out:
# (17016, 4)
# (5672, 4)

# %%
print(len(repeated_ids_labels_train))
print(len(repeated_ids_labels_val))
np.savetxt("ids_and_labels_train_repeated.csv", ids_labels_train, delimiter=",", fmt='%s')
np.savetxt("ids_and_labels_val_repeated.csv", ids_labels_val, delimiter=",", fmt='%s')
# Out:
# 17024
# 5664

# %%
class SN7Dataset(Dataset):
    
    def __init__(self, transform=None, train=True):
        
        if train == True:
            self.img_ids_labels = pd.read_csv("ids_and_labels_train_repeated.csv", header = None) 
        else:
            self.img_ids_labels = pd.read_csv("ids_and_labels_val_repeated.csv", header = None)
            
        self.img_dir = '/local/home/stuff/datasets/Challenge_7/train'
        self.transform = transform
        
    def __getitem__(self, idx):
        
        image_id, patch_id = self.img_ids_labels.iloc[idx, 0].split("!")[1],self.img_ids_labels.iloc[idx, 0].split("!")[0]
        pattern = "mosaic_(.*?).tif"
        location_id = re.search(pattern, image_id).group(1)
        #print(image_id)
        #print(location_id)
        img_path = os.path.join(self.img_dir, location_id, 'images', image_id )
        image = torchvision.transforms.ToTensor()(Image.open(img_path))[0:3,:,:]  #TAKE RGB CHANNELS ONLY FOR RESNET COMPATIBILITY!!!
        
        image_padded = torch.nn.functional.pad(image, pad=(0, 1024 - image.shape[2], 0, 1024 - image.shape[1]))
        patches = image_padded.unfold(1, 256, 256).unfold(2, 256, 256)
        patches = patches.reshape(3, -1, 256, 256)
        patches = patches.permute(1,0,2,3)
        
        image = patches[int(patch_id)]
        
        label = torch.from_numpy(np.asarray(self.img_ids_labels.iloc[idx, 3]))
        
        #patches = patches.view(-1, 3, 256, 256)
        #print(patches.shape)
        #label = label.flatten()
        #label = label.type(torch.LongTensor)
        
        if self.transform:
            image = self.transform(image)
                
            
        #if self.target_transform:
            #label = self.target_transform(label)
            
        
        return image, label
        
    def __len__(self):
        
        return len(self.img_ids_labels)

# %%
class GaussianBlur(object):
    def __init__(self, p):
        self.p = p

    def __call__(self, img):
        if np.random.rand() < self.p:
            sigma = np.random.rand() * 0.9 + 0.1
            #return img.filter(ImageFilter.GaussianBlur(sigma))
            transformed = transforms.functional.gaussian_blur(img, kernel_size=7, sigma=sigma)
            #print('after gaussian blur:', torch.sum(torch.isnan(transformed)) )
            return transformed
        else:
            return img


class Solarization(object):
    def __init__(self, p):
        self.p = p

    def __call__(self, img):
        if np.random.rand() < self.p:
            #return ImageOps.solarize(img)
            transformed = transforms.functional.solarize(img, threshold=0.5)
            #print('after solarization:', torch.sum(torch.isnan(transformed)) )
            return transformed
        else:
            return img
        
class Crop(object):
    def __call__(self, img):
        top = int(32*np.random.rand())
        left = int(32*np.random.rand())
        height = 256
        width = 256
        transformed = torch.empty(img.shape[0], 3, 224, 224)
        print(img.shape[0])
        for i in range(16):
            transformed[i] = torchvision.transforms.functional.resized_crop(img[i], top = top, left = left, height = height, width = width, size = 224)
            plt.imshow(transformed[i].permute(1,2,0))
        return transformed

# %%
#INSTANTIATE DATASETS

batch_size = 1

transform = transforms.Compose(
            [
                transforms.RandomCrop(
                    224
                ),
                #Crop(),
                transforms.RandomApply(
                    [
                        transforms.ColorJitter(
                            brightness=0.2, contrast=0.2, saturation=0.1, hue=0.1
                        )
                    ],
                    p=1.0,
                ),
                transforms.RandomHorizontalFlip(p=0.5),
                transforms.RandomGrayscale(p=0.5),
                GaussianBlur(p=1.0),
                Solarization(p=0.05),
                #transforms.ToTensor(),
                transforms.Normalize(
                    mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5]
                ),
            ]
        )

#transform = transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
train_dataset = SN7Dataset(train=True, transform = transform)
val_dataset = SN7Dataset(train=False, transform = transform)

train_loader = DataLoader(dataset=train_dataset, batch_size = batch_size, shuffle = True)
val_loader = DataLoader(dataset=val_dataset, batch_size = batch_size, shuffle = True)

# %%
def imshow(img):
    img = img / 2 + 0.5  # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(train_loader)
images, labels = dataiter.next()
print(torch.sum(torch.isnan(images)))
print(torch.sum(torch.isinf(images)))
print(torch.unique(images))
print(labels)

# show images
imshow(torchvision.utils.make_grid(images))
# Out:
# tensor(0)
# tensor(0)
# tensor([-9.6408e-01, -9.6287e-01, -9.6252e-01,  ..., -5.9605e-06,
#         -3.6359e-06, -2.0266e-06])
# tensor([29])

# %% [markdown]
# # TEMPORAL DATASET CLASS

# %%
class SN7Dataset(Dataset):
    
    def __init__(self, transform=None, train=True):
        
        if train == True:
            self.img_ids_labels = pd.read_csv("ids_and_labels_train_repeated.csv", header = None) 
        else:
            self.img_ids_labels = pd.read_csv("ids_and_labels_val_repeated.csv", header = None)
            
        self.img_dir = '/local/home/stuff/datasets/Challenge_7/train'
        self.transform = transform
        
    def __getitem__(self, idx):
        
        image_id, patch_id = self.img_ids_labels.iloc[idx, 0].split("!")[1],self.img_ids_labels.iloc[idx, 0].split("!")[0]
        pattern = "mosaic_(.*?).tif"
        location_id = re.search(pattern, image_id).group(1)
        contain_values = self.img_ids_labels[self.img_ids_labels[0].str.contains(location_id) & self.img_ids_labels[0].str.startswith(patch_id+'!')] 
        print(image_id)
        print(location_id)
        print(patch_id)
        print(contain_values)
        
        image_2_full = contain_values.sample().iloc[0, 0]
        print('image2:',image_2_full)
        image_id_2, patch_id_2 = image_2_full.split("!")[1],image_2_full.split("!")[0]
        pattern_2 = "mosaic_(.*?).tif"
        location_id_2 = re.search(pattern_2, image_id_2).group(1)
        
        img_path = os.path.join(self.img_dir, location_id, 'images', image_id )
        image = torchvision.transforms.ToTensor()(Image.open(img_path))[0:3,:,:]  #TAKE RGB CHANNELS ONLY FOR RESNET COMPATIBILITY!!!
        
        image_padded = torch.nn.functional.pad(image, pad=(0, 1024 - image.shape[2], 0, 1024 - image.shape[1]))
        patches = image_padded.unfold(1, 256, 256).unfold(2, 256, 256)
        patches = patches.reshape(3, -1, 256, 256)
        patches = patches.permute(1,0,2,3)
        
        image = patches[int(patch_id)]
        
        label = torch.from_numpy(np.asarray(self.img_ids_labels.iloc[idx, 3]))
        
        img_path_2 = os.path.join(self.img_dir, location_id_2, 'images', image_id_2 )
        image_2 = torchvision.transforms.ToTensor()(Image.open(img_path_2))[0:3,:,:]  #TAKE RGB CHANNELS ONLY FOR RESNET COMPATIBILITY!!!
        
        image_padded_2 = torch.nn.functional.pad(image_2, pad=(0, 1024 - image_2.shape[2], 0, 1024 - image_2.shape[1]))
        patches_2 = image_padded_2.unfold(1, 256, 256).unfold(2, 256, 256)
        patches_2 = patches_2.reshape(3, -1, 256, 256)
        patches_2 = patches_2.permute(1,0,2,3)
        
        image_2 = patches_2[int(patch_id_2)]
        
        
        
        #patches = patches.view(-1, 3, 256, 256)
        #print(patches.shape)
        #label = label.flatten()
        #label = label.type(torch.LongTensor)
        
        if self.transform:
            image = self.transform(image)
            image_2 = self.transform(image_2)
                
            
        #if self.target_transform:
            #label = self.target_transform(label)
            
        
        return image, image_2, label
        
    def __len__(self):
        
        return len(self.img_ids_labels)

# %%
#transform = transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
transform = transforms.Compose(
            [
                transforms.RandomCrop(
                    224
                ),
                #Crop(),
                #transforms.RandomApply(
                    #[
                       # transforms.ColorJitter(
                            #brightness=0.2, contrast=0.2, saturation=0.1, hue=0.1
                        #)
                    #],
                   # p=1.0,
                #),
                #transforms.RandomHorizontalFlip(p=0.5),
                #transforms.RandomGrayscale(p=0.5),
                #GaussianBlur(p=1.0),
                #Solarization(p=0.05),
                #transforms.ToTensor(),
                transforms.Normalize(
                    mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5]
                ),
            ]
        )
train_dataset = SN7Dataset(train=True, transform = transform)
val_dataset = SN7Dataset(train=False, transform = transform)

train_loader = DataLoader(dataset=train_dataset, batch_size = batch_size, shuffle = True)
val_loader = DataLoader(dataset=val_dataset, batch_size = batch_size, shuffle = True)

# %%
def imshow(img):
    img = img / 2 + 0.5  # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(train_loader)
images, images_2, labels = dataiter.next()
#print(torch.sum(torch.isnan(images)))
#print(torch.sum(torch.isinf(images)))
#print(torch.unique(images))
#print(labels)

# show images
imshow(torchvision.utils.make_grid(images))
imshow(torchvision.utils.make_grid(images_2))
# Out:
# global_monthly_2019_07_mosaic_L15-0614E-0946N_2459_4406_13.tif
# L15-0614E-0946N_2459_4406_13
# 8
#                                                        0              1  \
# 998    8!global_monthly_2018_04_mosaic_L15-0614E-0946...  San Sebastián
# 1203   8!global_monthly_2018_05_mosaic_L15-0614E-0946...  San Sebastián
# 1749   8!global_monthly_2018_06_mosaic_L15-0614E-0946...  San Sebastián
# 3790   8!global_monthly_2019_01_mosaic_L15-0614E-0946...  San Sebastián
# 5309   8!global_monthly_2019_02_mosaic_L15-0614E-0946...  San Sebastián
# 5594   8!global_monthly_2019_04_mosaic_L15-0614E-0946...  San Sebastián
# 7216   8!global_monthly_2019_07_mosaic_L15-0614E-0946...  San Sebastián
# 8169   8!global_monthly_2020_01_mosaic_L15-0614E-0946...  San Sebastián
# 8924   8!global_monthly_2019_08_mosaic_L15-0614E-0946...  San Sebastián
# 11705  8!global_monthly_2019_06_mosaic_L15-0614E-0946...  San Sebastián
# 11991  8!global_monthly_2019_11_mosaic_L15-0614E-0946...  San Sebastián
# 12449  8!global_monthly_2018_07_mosaic_L15-0614E-0946...  San Sebastián
# 13343  8!global_monthly_2018_08_mosaic_L15-0614E-0946...  San Sebastián
# 13406  8!global_monthly_2018_03_mosaic_L15-0614E-0946...  San Sebastián
# 15398  8!global_monthly_2018_12_mosaic_L15-0614E-0946...  San Sebastián
# 16040  8!global_monthly_2019_05_mosaic_L15-0614E-0946...  San Sebastián
# 16168  8!global_monthly_2019_10_mosaic_L15-0614E-0946...  San Sebastián
#
#            2   3
# 998    Cusco  11
# 1203   Cusco  11
# 1749   Cusco  11
# 3790   Cusco  11
# 5309   Cusco  11
# 5594   Cusco  11
# 7216   Cusco  11
# 8169   Cusco  11
# 8924   Cusco  11
# 11705  Cusco  11
# 11991  Cusco  11
# 12449  Cusco  11
# 13343  Cusco  11
# 13406  Cusco  11
# 15398  Cusco  11
# 16040  Cusco  11
# 16168  Cusco  11
# image2: 8!global_monthly_2018_03_mosaic_L15-0614E-0946N_2459_4406_13.tif
# global_monthly_2019_12_mosaic_L15-1848E-0793N_7394_5018_13.tif
# L15-1848E-0793N_7394_5018_13
# 12
#                                                        0          1         2  \
# 1921   12!global_monthly_2019_05_mosaic_L15-1848E-079...  Melbourne  Victoria
# 2113   12!global_monthly_2018_08_mosaic_L15-1848E-079...  Melbourne  Victoria
# 2678   12!global_monthly_2019_06_mosaic_L15-1848E-079...  Melbourne  Victoria
# 3970   12!global_monthly_2018_03_mosaic_L15-1848E-079...  Melbourne  Victoria
# 6602   12!global_monthly_2019_10_mosaic_L15-1848E-079...  Melbourne  Victoria
# 6944   12!global_monthly_2019_02_mosaic_L15-1848E-079...  Melbourne  Victoria
# 7530   12!global_monthly_2018_12_mosaic_L15-1848E-079...  Melbourne  Victoria
# 7786   12!global_monthly_2019_11_mosaic_L15-1848E-079...  Melbourne  Victoria
# 8203   12!global_monthly_2018_07_mosaic_L15-1848E-079...  Melbourne  Victoria
# 8232   12!global_monthly_2019_01_mosaic_L15-1848E-079...  Melbourne  Victoria
# 8877   12!global_monthly_2018_11_mosaic_L15-1848E-079...  Melbourne  Victoria
# 10179  12!global_monthly_2019_12_mosaic_L15-1848E-079...  Melbourne  Victoria
# 11795  12!global_monthly_2018_02_mosaic_L15-1848E-079...  Melbourne  Victoria
# 14182  12!global_monthly_2019_03_mosaic_L15-1848E-079...  Melbourne  Victoria
# 14739  12!global_monthly_2019_08_mosaic_L15-1848E-079...  Melbourne  Victoria
#
#        3
# 1921   1
# 2113   1
# 2678   1
# 3970   1
# 6602   1
# 6944   1
# 7530   1
# 7786   1
# 8203   1
# 8232   1
# 8877   1
# 10179  1
# 11795  1
# 14182  1
# 14739  1
# image2: 12!global_monthly_2019_05_mosaic_L15-1848E-0793N_7394_5018_13.tif
# global_monthly_2019_05_mosaic_L15-0457E-1135N_1831_3648_13.tif
# L15-0457E-1135N_1831_3648_13
# 13
#                                                        0    1  \
# 731    13!global_monthly_2018_11_mosaic_L15-0457E-113...  NaN
# 1947   13!global_monthly_2018_06_mosaic_L15-0457E-113...  NaN
# 1951   13!global_monthly_2019_09_mosaic_L15-0457E-113...  NaN
# 4181   13!global_monthly_2019_08_mosaic_L15-0457E-113...  NaN
# 5356   13!global_monthly_2018_12_mosaic_L15-0457E-113...  NaN
# 6935   13!global_monthly_2019_10_mosaic_L15-0457E-113...  NaN
# 7555   13!global_monthly_2019_07_mosaic_L15-0457E-113...  NaN
# 9726   13!global_monthly_2019_06_mosaic_L15-0457E-113...  NaN
# 9993   13!global_monthly_2018_05_mosaic_L15-0457E-113...  NaN
# 10933  13!global_monthly_2019_02_mosaic_L15-0457E-113...  NaN
# 12425  13!global_monthly_2018_08_mosaic_L15-0457E-113...  NaN
# 12460  13!global_monthly_2019_11_mosaic_L15-0457E-113...  NaN
# 13253  13!global_monthly_2018_01_mosaic_L15-0457E-113...  NaN
# 14706  13!global_monthly_2019_01_mosaic_L15-0457E-113...  NaN
# 14902  13!global_monthly_2018_10_mosaic_L15-0457E-113...  NaN
# 15788  13!global_monthly_2019_05_mosaic_L15-0457E-113...  NaN
# 15817  13!global_monthly_2018_04_mosaic_L15-0457E-113...  NaN
# 16409  13!global_monthly_2018_03_mosaic_L15-0457E-113...  NaN
#
#                       2  3
# 731    Estado de México  7
# 1947   Estado de México  7
# 1951   Estado de México  7
# 4181   Estado de México  7
# 5356   Estado de México  7
# 6935   Estado de México  7
# 7555   Estado de México  7
# 9726   Estado de México  7
# 9993   Estado de México  7
# 10933  Estado de México  7
# 12425  Estado de México  7
# 12460  Estado de México  7
# 13253  Estado de México  7
# 14706  Estado de México  7
# 14902  Estado de México  7
# 15788  Estado de México  7
# 15817  Estado de México  7
# 16409  Estado de México  7
# image2: 13!global_monthly_2019_05_mosaic_L15-0457E-1135N_1831_3648_13.tif
# global_monthly_2019_08_mosaic_L15-1204E-1202N_4816_3380_13.tif
# L15-1204E-1202N_4816_3380_13
# 6
#                                                        0        1        2   3
# 172    6!global_monthly_2018_03_mosaic_L15-1204E-1202...  القاهرة  القاهرة  27
# 316    6!global_monthly_2019_04_mosaic_L15-1204E-1202...  القاهرة  القاهرة  27
# 1211   6!global_monthly_2018_07_mosaic_L15-1204E-1202...  القاهرة  القاهرة  27
# 1713   6!global_monthly_2019_07_mosaic_L15-1204E-1202...  القاهرة  القاهرة  27
# 2690   6!global_monthly_2019_03_mosaic_L15-1204E-1202...  القاهرة  القاهرة  27
# 3888   6!global_monthly_2018_11_mosaic_L15-1204E-1202...  القاهرة  القاهرة  27
# 6178   6!global_monthly_2019_01_mosaic_L15-1204E-1202...  القاهرة  القاهرة  27
# 8795   6!global_monthly_2019_08_mosaic_L15-1204E-1202...  القاهرة  القاهرة  27
# 9315   6!global_monthly_2018_08_mosaic_L15-1204E-1202...  القاهرة  القاهرة  27
# 9550   6!global_monthly_2019_05_mosaic_L15-1204E-1202...  القاهرة  القاهرة  27
# 10170  6!global_monthly_2018_09_mosaic_L15-1204E-1202...  القاهرة  القاهرة  27
# 10199  6!global_monthly_2018_10_mosaic_L15-1204E-1202...  القاهرة  القاهرة  27
# 11556  6!global_monthly_2018_02_mosaic_L15-1204E-1202...  القاهرة  القاهرة  27
# 11945  6!global_monthly_2018_12_mosaic_L15-1204E-1202...  القاهرة  القاهرة  27
# 12714  6!global_monthly_2017_09_mosaic_L15-1204E-1202...  القاهرة  القاهرة  27
# 14755  6!global_monthly_2017_11_mosaic_L15-1204E-1202...  القاهرة  القاهرة  27
# 15583  6!global_monthly_2019_06_mosaic_L15-1204E-1202...  القاهرة  القاهرة  27
# 16331  6!global_monthly_2018_04_mosaic_L15-1204E-1202...  القاهرة  القاهرة  27
# image2: 6!global_monthly_2018_10_mosaic_L15-1204E-1202N_4816_3380_13.tif
# global_monthly_2018_12_mosaic_L15-1014E-1375N_4056_2688_13.tif
# L15-1014E-1375N_4056_2688_13
# 2
#                                                        0    1        2   3
# 3563   2!global_monthly_2018_04_mosaic_L15-1014E-1375...  NaN  England  17
# 3574   2!global_monthly_2018_07_mosaic_L15-1014E-1375...  NaN  England  17
# 4375   2!global_monthly_2018_08_mosaic_L15-1014E-1375...  NaN  England  17
# 4727   2!global_monthly_2019_06_mosaic_L15-1014E-1375...  NaN  England  17
# 5550   2!global_monthly_2019_12_mosaic_L15-1014E-1375...  NaN  England  17
# 6229   2!global_monthly_2018_11_mosaic_L15-1014E-1375...  NaN  England  17
# 9808   2!global_monthly_2019_03_mosaic_L15-1014E-1375...  NaN  England  17
# 10051  2!global_monthly_2018_09_mosaic_L15-1014E-1375...  NaN  England  17
# 10776  2!global_monthly_2019_04_mosaic_L15-1014E-1375...  NaN  England  17
# 11108  2!global_monthly_2018_02_mosaic_L15-1014E-1375...  NaN  England  17
# 12284  2!global_monthly_2019_05_mosaic_L15-1014E-1375...  NaN  England  17
# 12659  2!global_monthly_2019_09_mosaic_L15-1014E-1375...  NaN  England  17
# 14516  2!global_monthly_2018_12_mosaic_L15-1014E-1375...  NaN  England  17
# 15025  2!global_monthly_2019_01_mosaic_L15-1014E-1375...  NaN  England  17
# image2: 2!global_monthly_2019_03_mosaic_L15-1014E-1375N_4056_2688_13.tif
